# %% [markdown]
# ## ***Visualização de variáveis e textos***

# %%
print("Conhecendo o comando print")

x = 8
print(x)
# Out:
# Conhecendo o comando print
# 8

# %%
y = 10
soma = x + y
print(soma)
# Out:
# 18

# %%
nome = 'Maylon Vinicius'
print(nome)
# Out:
# Maylon Vinicius

# %% [markdown]
# Concatenação

# %%
x = 5
print('O valor de x é', x)
# Out:
# O valor de x é 5

# %%
print('O valor de x é', x, 'e o dobro é', x * 2)
# Out:
# O valor de x é 5 e o dobro é 10

# %%
print('Eu,', nome, 'tirei', x, 'na prova de Pyton')
# Out:
# Eu, Maylon Vinicius tirei 5 na prova de Pyton

# %%
y = 10; z = 20 + x - y

print('Declarar variáveis na mesma linha:', y, z)
# Out:
# Declarar variáveis na mesma linha: 10 15

# %% [markdown]
# Type

# %%
x = 10
type(x)
print('x', type(x))

nome = 'Maylon'
print('nome', type(nome))

num = '100'
num_convert = int(num)    #Converter variável
print('num', type(num))
print('num_convert', type(num_convert))

num_float = float(num)
print('num_float', num_float)
# Out:
# x <class 'int'>
# nome <class 'str'>
# num <class 'str'>
# num_convert <class 'int'>
# num_float 100.0

# %% [markdown]
# Input
#
#
# *   Armazenar a informação digitada pelo usuário em uma variável
# *   O dado armazenado sempre será um texto

# %%
nome = input("Digite o nome do usuário ") # Aguarda o usuário digitar algo
print(nome)
# Out:
# Digite o nome do usuário Vini
# Vini

# %%
valor = input("Digite a nota ")

print(nome, 'sua nota foi', valor)
# Out:
# Digite a nota 10
# Vini sua nota foi 10

# %%
valor = input("Digite o valor do produto ")
print(valor)
# Out:
# Digite o valor do produto 100
# 100

# %%
desconto = valor - 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2171237004.py in <cell line: 0>()
# ----> 1 desconto = valor - 5
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
valor_convert = int(valor)      # Se for usar em outras partes do código
desconto = valor_convert - 5
print(desconto)
# Out:
# 95

# %%
desconto = int(valor) - 5     # Se for usar apenas nessa linha
print(desconto)
# Out:
# 95
